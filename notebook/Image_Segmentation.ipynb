# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

from scipy.signal import convolve2d
from scipy.ndimage import gaussian_filter
import math
from sklearn.cluster import KMeans
from skimage.measure import label
from scipy.ndimage import median_filter
from scipy.ndimage import sobel

# %% [markdown]
# #### Bai 1

# %%
image_path = r'D:\py\Digital_Image_Processing\Image\Image_for_Frequency\demo_fft_2.jpg'
I = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
H = np.array([[1, -1]]) # Dao ham bac 1
H_T = H.T

Y1 = convolve2d(I, H, "same", "symm")
Y2 = convolve2d(I, H_T, "same", "symm")
Y = np.abs(Y1) + np.abs(Y2)

plt.figure(figsize= (10, 8))
plt.subplot(2, 2, 1)
plt.imshow(I, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(np.abs(Y1), cmap='gray')
plt.title("Y1 Image")
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(np.abs(Y2), cmap='gray')
plt.title("Y2 Image")
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(Y, cmap='gray')
plt.title("Y Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(599.5), np.float64(361.5), np.float64(-0.5))

# %%
H = np.array([[1, -2, 1],
              [1, -2, 1],
              [1, -2, 1]]) # Dao ham bac 2 nen xay ra gia tri am duong gan ke nhau -> can know edge from dark to light or from light to dark base negative or positive
H_T = H.T

Y1 = convolve2d(I, H, "same", "symm")
Y2 = convolve2d(I, H_T, "same", "symm")
Y = np.abs(Y1) + np.abs(Y2)

plt.figure(figsize= (10, 8))
plt.subplot(2, 2, 1)
plt.imshow(I, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(np.abs(Y1), cmap='gray')
plt.title("Y1 Image")
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(np.abs(Y2), cmap='gray')
plt.title("Y2 Image")
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(Y, cmap='gray')
plt.title("Y Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(599.5), np.float64(361.5), np.float64(-0.5))

# %%
image_path = r'D:\py\Digital_Image_Processing\Image\Image_for_Frequency\cameraman.tif'
I = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
H = np.array([[1, -1]]) # Dao ham bac 1
H_T = H.T

Y1 = convolve2d(I, H, "same", "symm")
Y2 = convolve2d(I, H_T, "same", "symm")
Y = np.abs(Y1) + np.abs(Y2)

plt.figure(figsize= (10, 8))
plt.subplot(2, 2, 1)
plt.imshow(I, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(np.abs(Y1), cmap='gray')
plt.title("Y1 Image")
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(np.abs(Y2), cmap='gray')
plt.title("Y2 Image")
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(Y, cmap='gray')
plt.title("Y Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
H = np.array([[1, -2, 1],
              [1, -2, 1],
              [1, -2, 1]]) # Dao ham bac 2 nen xay ra gia tri am duong gan ke nhau -> can know edge from dark to light or from light to dark base negative or positive
H_T = H.T

Y1 = convolve2d(I, H, "same", "symm")
Y2 = convolve2d(I, H_T, "same", "symm")
Y = np.abs(Y1) + np.abs(Y2)

plt.figure(figsize= (10, 8))
plt.subplot(2, 2, 1)
plt.imshow(I, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(np.abs(Y1), cmap='gray')
plt.title("Y1 Image")
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(np.abs(Y2), cmap='gray')
plt.title("Y2 Image")
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(Y, cmap='gray')
plt.title("Y Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %%
image_path = r'D:\py\Digital_Image_Processing\Image\19.png'
I = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
H = np.array([[1, -1]]) # Dao ham bac 1
H_T = H.T

Y1 = convolve2d(I, H, "same", "symm")
Y2 = convolve2d(I, H_T, "same", "symm")
Y = np.abs(Y1) + np.abs(Y2)

plt.figure(figsize= (10, 8))
plt.subplot(2, 2, 1)
plt.imshow(I, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(np.abs(Y1), cmap='gray')
plt.title("Y1 Image")
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(np.abs(Y2), cmap='gray')
plt.title("Y2 Image")
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(Y, cmap='gray')
plt.title("Y Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(511.5), np.float64(767.5), np.float64(-0.5))

# %%
H = np.array([[1, -2, 1],
              [1, -2, 1],
              [1, -2, 1]]) # Dao ham bac 2 nen xay ra gia tri am duong gan ke nhau -> can know edge from dark to light or from light to dark base negative or positive
H_T = H.T

Y1 = convolve2d(I, H, "same", "symm")
Y2 = convolve2d(I, H_T, "same", "symm")
Y = np.abs(Y1) + np.abs(Y2)

plt.figure(figsize= (10, 8))
plt.subplot(2, 2, 1)
plt.imshow(I, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(np.abs(Y1), cmap='gray')
plt.title("Y1 Image")
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(np.abs(Y2), cmap='gray')
plt.title("Y2 Image")
plt.axis('off')

plt.subplot(2, 2, 4)
plt.imshow(Y, cmap='gray')
plt.title("Y Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(511.5), np.float64(767.5), np.float64(-0.5))
# Error in callback <function flush_figures at 0x00000165C2BB0550> (for post_execute), with arguments args (),kwargs {}:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\matplotlib_inline\backend_inline.py:126, in flush_figures()
#     123 if InlineBackend.instance().close_figures:
#     124     # ignore the tracking, just draw and close all figures
#     125     try:
# --> 126         return show(True)
#     127     except Exception as e:
#     128         # safely show traceback if in IPython, else raise
#     129         ip = get_ipython()
#
# ...

# %% [markdown]
# #### Bai 2

# %%
image_path = r'D:\py\Digital_Image_Processing\Image\Image_for_Frequency\demo_fft_2.jpg'
I = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# %%
# Create a Gaussian kernel
G = cv2.getGaussianKernel(7, 2)
G = G @ G.T

if len(I.shape) == 3:
    I = cv2.cvtColor(I, cv2.COLOR_BGR2GRAY)

# Gaussian blur and differences
Y1 = convolve2d(I, G, mode="same", boundary="symm")
Y2 = convolve2d(Y1, G, mode="same", boundary="symm")
Y3 = Y1 - Y2     # Difference between first and second blur
Y4 = I - Y1      # High-frequency component removed by first blur

# Display results
plt.figure(figsize=(10, 8))

plt.subplot(2, 2, 1)
plt.imshow(I, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(Y3, cmap='gray')  # Low-frequency changes
plt.title("Y3 = Y1 - Y2")
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(Y4, cmap='gray')  # High-pass details
plt.title("Y4 = I - Y1")
plt.axis('off')

plt.tight_layout()
plt.show()

# %%
image_path = r'D:\py\Digital_Image_Processing\Image\Image_for_Frequency\cameraman.tif'
I = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

G = cv2.getGaussianKernel(7, 2)
G = G @ G.T

Y1 = convolve2d(I, G, "same", "symm")
Y2 = convolve2d(Y1, G, "same", "symm")
Y3 = Y1 - Y2
Y4 = I - Y1

plt.figure(figsize= (10, 8))
plt.subplot(2, 2, 1)
plt.imshow(I, cmap='gray')
plt.title("Original Image")
plt.axis('off')

plt.subplot(2, 2, 2)
plt.imshow(Y3, cmap='gray')
plt.title("Y3 Image")
plt.axis('off')

plt.subplot(2, 2, 3)
plt.imshow(Y4, cmap='gray')
plt.title("Y4 Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(255.5), np.float64(255.5), np.float64(-0.5))

# %% [markdown]
# #### Adaptive K-means algorithm

# %%
image_path = r'D:\py\Digital_Image_Processing\Image\3.png'
I = cv2.imread(image_path, cv2.IMREAD_COLOR_RGB)

# %% [markdown]
# ##### Step1: Image preprocessing

# %%
# Normalize RGB to [0, 1]
r, g, b = I[:,:,0] / 255.0, I[:,:,1] / 255.0, I[:,:,2] / 255.0

# Apply gamma correction
def gamma_correct(c):
    return np.where(c > 0.04045, ((c + 0.055) / 1.055) ** 2.4, c / 12.92)

R = gamma_correct(r)
G = gamma_correct(g)
B = gamma_correct(b)

# # Convert RGB to XYZ
X = 0.4124 * R + 0.3567 * G + 0.1805 * B
Y = 0.2126 * R + 0.7152 * G + 0.0722 * B
Z = 0.0193 * R + 0.1192 * G + 0.9505 * B


# # Normalize for D65 white point
Xn, Yn, Zn = 0.95047, 1.00000, 1.08883
x = X / Xn
y = Y / Yn
z = Z / Zn

# Nonlinear transformation
def f(t):
    delta = 6/29
    return np.where(t > delta**3, t ** (1/3), (t / (3 * delta**2)) + 4/29)

fx = f(x)
fy = f(y)
fz = f(z)

# Calculate L*a*b*
L = 116 * fy - 16
a = 500 * (fx - fy)
b = 200 * (fy - fz)
# a = 500 * (fx - fz)
# b = 200 * (fx - fz)

L = np.zeros_like(fy)

# Stack to visualize
lab_image = np.stack([L, a, b], axis=-1)

# Normalize for visualization (convert to 0–255)
L_vis = np.clip(L * (255 / 100), 0, 255)
a_vis = np.clip(a + 128, 0, 255)
b_vis = np.clip(b + 128, 0, 255)
lab_vis = np.stack([L_vis, a_vis, b_vis], axis=-1).astype(np.uint8)

# Display
plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(I)
plt.title("Original RGB Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(lab_vis, cmap="gray")
plt.title("Converted L*a*b* Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(767.5), np.float64(511.5), np.float64(-0.5))

# %% [markdown]
# ##### Step2: K-means algorithm with channel a, b with manual

# %%
def kmeans_manual (data, K,  max_iters = 100, tol = 1e-4):

    N, D = data.shape

    np.random.seed(42) # Make the random is same with other time 
    initial_indices = np.random.choice(N, K, replace = False) # No same value for same point
    centeroids = data[initial_indices]
    
    for iter in range(max_iters):
        # Calculate distance and labels
        distance = np.linalg.norm(data[:, np.newaxis] - centeroids, axis=2)
        labels = np.argmin(distance, axis=1)

        # Create new centeroid
        new_centeroid = np.zeros((K, D))
        for k in range(K):
            clustered_point = data[labels == k]
            if len(clustered_point) > 0:
                new_centeroid[k] = np.mean(clustered_point, axis = 0)
            else:
                new_centeroid[k] = data[np.random.choice(N)]

        # Check 
        if np.linalg.norm(new_centeroid - centeroids) < tol:
            print(f"Hoi tu sau {iter} vong lap")
            break
        
        centeroids = new_centeroid

    return labels, centeroids

# %%
ab = np.stack([a, b], axis=-1)
h, w, _ = ab.shape
ab_flat = ab.reshape((-1, 2))

labels, centroids = kmeans_manual(ab_flat, K=3)

# Chuyển về dạng ảnh phân đoạn
segmentation = labels.reshape((h, w))

# Hiển thị kết quả
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.imshow(I)
plt.title("Original RGB Image")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(lab_vis, cmap="gray")
plt.title("Converted L*a*b* Image")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(segmentation, cmap='gray')
plt.axis('off')
plt.title(f"Final Segmentation with K={K}")
# Out:
# Hoi tu sau 16 vong lap
# Text(0.5, 1.0, 'Final Segmentation with K=3')

# %% [markdown]
# ##### Step2: K-means algorithm with channel a, b with function

# %%
# Reshape a* and b* channels for clustering (flatten into 2D points)
ab = np.stack([a, b], axis=-1)
h, w, _ = ab.shape
ab_flat_1 = ab.reshape((-1, 2))

# Apply K-means clustering
K = 3  # Choose number of clusters
kmeans = KMeans(n_clusters=K, n_init=10)
labels = kmeans.fit_predict(ab_flat_1)

# Reshape labels back to image shape
segmentation = labels.reshape((h, w))

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.imshow(lab_vis, cmap="gray")
plt.title("Converted L*a*b* Image")
plt.axis('off')

plt.subplot(1, 2, 2)
plt.imshow(segmentation, cmap='gray')
plt.axis('off')
plt.title(f"Final Segmentation with K={K}")
# Out:
# Text(0.5, 1.0, 'Final Segmentation with K=3')

# %% [markdown]
# ##### Step3: Thresholding

# %%
# # Chuẩn hóa segmentation về [0, 1]
# normalized = segmentation.astype(np.float32) / segmentation.max()

# # Ngưỡng nhị phân với threshold thuoc [0, 1]
# threshold = 0.2
# binary = (normalized > threshold).astype(np.uint8)

# # Hiển thị kết quả
# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.imshow(segmentation, cmap='gray')
# plt.axis('off')
# plt.title(f"Final Segmentation with K={K}")

# plt.subplot(1, 2, 2)
# plt.imshow(binary, cmap='gray')
# plt.title(f"Binary mask (threshold = {threshold})")
# plt.axis('off')

# %% [markdown]
# ##### Step4: Canny operator

# %%
# # Apply Sobel filters
# Gx = sobel(binary, axis=1)  # Horizontal gradient
# Gy = sobel(binary, axis=0)  # Vertical gradient
    
# # Compute gradient magnitude
# magnitude = np.sqrt(Gx**2 + Gy**2)

# # Compute gradient direction (in radians, then convert to degrees)
# direction = np.arctan2(Gy, Gx) * (180 / np.pi)

# # Normalize direction to [0, 180]
# direction = direction % 180

# # Quantize direction to 0, 45, 90, 135 degrees
# direction = np.round(direction / 45) * 45
# direction = direction.astype(int)
# rows, cols = magnitude.shape
# suppressed = np.zeros_like(magnitude)

# for i in range(1, rows-1):
#     for j in range(1, cols-1):
#         angle = direction[i, j]
#         mag = magnitude[i, j]
        
#         # Compare with neighbors based on direction
#         if angle == 0:  # Horizontal (left, right)
#             neighbors = [magnitude[i, j-1], magnitude[i, j+1]]
#         elif angle == 45:  # Diagonal (top-left, bottom-right)
#             neighbors = [magnitude[i-1, j-1], magnitude[i+1, j+1]]
#         elif angle == 90:  # Vertical (top, bottom)
#             neighbors = [magnitude[i-1, j], magnitude[i+1, j]]
#         else:  # 135° (top-right, bottom-left)
#             neighbors = [magnitude[i-1, j+1], magnitude[i+1, j-1]]
        
#         # Keep pixel if it's the maximum
#         if mag >= max(neighbors):
#             suppressed[i, j] = mag


# low_ratio, high_ratio = 0.1, 0.3
# max_magnitude = np.max(suppressed)
# low_threshold = low_ratio * max_magnitude
# high_threshold = high_ratio * max_magnitude

# # Initialize output
# thresholded = np.zeros_like(suppressed, dtype=np.uint8)

# # Apply thresholds
# thresholded[suppressed > high_threshold] = 255  # Strong edges
# thresholded[(suppressed > low_threshold) & (suppressed <= high_threshold)] = 128

# plt.figure(figsize=(12, 6))
# plt.subplot(1, 2, 1)
# plt.imshow(binary, cmap='gray')
# plt.title(f"Binary mask (threshold = {threshold})")
# plt.axis('off')

# plt.subplot(1, 2, 2)
# plt.imshow(thresholded, cmap='gray')
# plt.title("Canny Edges")
# plt.axis('off')

# %% [markdown]
# ##### Result

# %%
# # Dùng phép giãn + đóng mạnh hơn để đảm bảo các đường bao khép kín
# se = cv2.getStructuringElement(cv2.MORPH_ELLIPSE, (10, 10))  # Tương đương disk radius 5
# closed_edges = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, se)

# # Điền kín vùng bao kín
# filled_regions = morphology.remove_small_holes(closed_edges.astype(bool), area_threshold=500)

# # Loại bỏ các vật nhỏ (lọc nhiễu)
# cleaned = morphology.remove_small_objects(filled_regions, min_size=500)

# # Gán nhãn vùng liên thông
# labeled_img = measure.label(cleaned)
# stats = measure.regionprops(labeled_img)

# # Lấy các nhãn hợp lệ theo diện tích
# min_area = 500
# valid_labels = [prop.label for prop in stats if prop.area >= min_area]

# # Hiển thị các vùng được tách ra từ ảnh gốc
# plt.figure(figsize=(10, 10))
# num_regions = len(valid_labels)
# rows = int(np.ceil(np.sqrt(num_regions)))
# cols = int(np.ceil(num_regions / rows))

# for i, label in enumerate(valid_labels, 1):
#     mask = labeled_img == label
    
#     # Áp dụng mặt nạ lên ảnh gốc (giả sử I là ảnh màu BGR)
#     masked_img = I.copy()
#     masked_img[~mask] = 0  # Đặt các pixel không thuộc vùng thành 0
    
#     plt.subplot(rows, cols, i)
#     plt.imshow(masked_img)  # Chuyển BGR sang RGB để hiển thị
#     plt.title(f'Vùng {i}')
#     plt.axis('off')
#     plt.tight_layout()
